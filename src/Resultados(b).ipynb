# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importación de datos

# %%
data_2 = pd.read_csv('tabla de resultados')
data_2.head()
# Out:
#    Unnamed: 0  DBO5_x  SS_x  Cluster_2    NT    PT  DEPURADORA_2  \
# 0           0     5.0   5.0          0  15.8  0.91             0
# 1           1     5.0   4.0          0  14.9  0.84             0
# 2           2     5.0   3.0          0   9.8  0.63             0
# 3           3     5.0   3.0          0   7.0  0.67             0
# 4           4     5.0   4.0          0   9.7  0.85             0
#
#    KMeans_Cluster_2
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# ## Cluster jerárquico vs kmeans

# %% [markdown]
# A continuación se representan los clusters obtenidos con ambas técnicas,y se realiza un value_counts,para ver como fue la clasificación

# %%
data_2["Cluster_2"].value_counts()
# Out:
# 0    433
# 1    175
# 3      9
# 2      7
# Name: Cluster_2, dtype: int64

# %%
data_2["KMeans_Cluster_2"].value_counts()
# Out:
# 0    251
# 4    195
# 1     96
# 3     71
# 2     11
# Name: KMeans_Cluster_2, dtype: int64

# %%
fig, ax = plt.subplots(2, 1, figsize = (6, 8))
sns.scatterplot("DBO5_x", "SS_x", data = data_2, hue = "Cluster_2", ax = ax[0]);
sns.scatterplot("DBO5_x", "SS_x", data = data_2, hue = "KMeans_Cluster_2",
                palette = "gist_stern", ax = ax[1]);
